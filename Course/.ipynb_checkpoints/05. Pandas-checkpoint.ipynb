# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 插播: 在 `matplotlib` 中顯示中文
#
# 這裡參考 Mosky 在, 比如說[這裡](https://github.com/moskytw/hypothesis-testing-with-python)的做法。
#
# 如果明明有的字型, `matplotlib` 說找不到的話, 有可能需要讓 `matplotlib` 清掉原本的 cache。
#
#     !rm -rf {mpl.get_cachedir()}
#     matplotlib.font_manager._rebuild()

# %%
import matplotlib as mpl

# %% [markdown]
# 使用 Google `Noto Sans CJK TC` 字型, 請到[這裡](https://www.google.com/get/noto/#sans-hant)下載。

# %%
mpl.rc('font',family ='Noto Sans CJK TC')

# %% [markdown]
# 如果你很好奇有什麼字型可以用...
#
#     [f.name for f in mpl.font_manager.fontManager.ttflist]

# %%
[f.name for f in mpl.font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'DejaVu Sans Display',
#  'cmr10',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'cmmi10',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXSizeFiveSym',
#  'cmtt10',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'cmss10',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'cmb10',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'cmsy10',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'Segoe Print',
#  'Cooper Black',
#  'Segoe UI Historic',
#  'Candara',
#  'Arial',
#  'Felix Titling',
#  'Corbel',
#  'Calibri',
#  'Verdana',
#  'Goudy Old Style',
#  'Kristen ITC',
#  'Gill Sans MT',
#  'Cambria',
#  'Comic Sans MS',
#  'Freestyle Script',
#  'Britannic Bold',
#  'Modern No. 20',
#  'Tahoma',
#  'Trebuchet MS',
#  'Vladimir Script',
#  'Palatino Linotype',
#  'Segoe Script',
#  'Myanmar Text',
#  'Tahoma',
#  'Bodoni MT',
#  'Microsoft PhagsPa',
#  'Eras Demi ITC',
#  'Calisto MT',
#  'Calibri',
#  'Gill Sans MT',
#  'Stencil',
#  'Lucida Sans',
#  'Gadugi',
#  'Noto Sans CJK TC',
#  'Imprint MT Shadow',
#  'Segoe UI',
#  'Haettenschweiler',
#  'Sylfaen',
#  'Consolas',
#  'SketchFlow Print',
#  'Lucida Sans Typewriter',
#  'STKaiti',
#  'Ebrima',
#  'Javanese Text',
#  'Dubai',
#  'Calibri',
#  'Copperplate Gothic Light',
#  'Bodoni MT',
#  'Franklin Gothic Heavy',
#  'Bookshelf Symbol 7',
#  'Calisto MT',
#  'Segoe UI',
#  'Constantia',
#  'Lucida Bright',
#  'Lucida Fax',
#  'Bodoni MT',
#  'Palatino Linotype',
#  'Segoe Marker',
#  'Segoe UI',
#  'Goudy Old Style',
#  'Segoe UI',
#  'Leelawadee UI',
#  'Algerian',
#  'Harlow Solid Italic',
#  'Kristen ITC',
#  'Constantia',
#  'Old English Text MT',
#  'Corbel',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Papyrus',
#  'Ink Free',
#  'Gloucester MT Extra Condensed',
#  'Bodoni MT',
#  'Informal Roman',
#  'Copperplate Gothic Light',
#  'Gill Sans Ultra Bold',
#  'Bell MT',
#  'Arial',
#  'Tw Cen MT Condensed',
#  'Wide Latin',
#  'Microsoft New Tai Lue',
#  'Lucida Fax',
#  'STXinwei',
#  'Goudy Stout',
#  'Lucida Sans Unicode',
#  'Palatino Linotype',
#  'Imprint MT Shadow',
#  'Eras Medium ITC',
#  'Eras Bold ITC',
#  'Book Antiqua',
#  'Californian FB',
#  'Lucida Sans',
#  'Malgun Gothic',
#  'Leelawadee UI',
#  'Snap ITC',
#  'Lucida Calligraphy',
#  'Wingdings',
#  'Century Schoolbook',
#  'Bodoni MT',
#  'STXihei',
#  'French Script MT',
#  'High Tower Text',
#  'Leelawadee UI',
#  'Curlz MT',
#  'Lucida Fax',
#  'Californian FB',
#  'Constantia',
#  'Times New Roman',
#  'Segoe UI',
#  'Microsoft Tai Le',
#  'Calibri',
#  'Algerian',
#  'Bodoni MT',
#  'Noto Sans CJK TC',
#  'STLiti',
#  'Symbol',
#  'Book Antiqua',
#  'Bernard MT Condensed',
#  'Noto Sans CJK TC',
#  'Noto Sans CJK TC',
#  'STLiti',
#  'Modern No. 20',
#  'Franklin Gothic Heavy',
#  'MV Boli',
#  'Bookman Old Style',
#  'Lucida Console',
#  'SimSun-ExtB',
#  'Segoe UI',
#  'Juice ITC',
#  'Magneto',
#  'French Script MT',
#  'Tw Cen MT Condensed',
#  'Agency FB',
#  'Lucida Fax',
#  'Franklin Gothic Book',
#  'Berlin Sans FB',
#  'Cambria',
#  'Corbel',
#  'Bodoni MT',
#  'Lucida Bright',
#  'Arial',
#  'Calisto MT',
#  'Verdana',
#  'Berlin Sans FB',
#  'Bodoni MT',
#  'Rage Italic',
#  'Jokerman',
#  'Noto Sans CJK TC',
#  'Microsoft Tai Le',
#  'Century Gothic',
#  'Gabriola',
#  'Franklin Gothic Medium Cond',
#  'Informal Roman',
#  'Palatino Linotype',
#  'Bell MT',
#  'Lucida Sans Typewriter',
#  'Perpetua Titling MT',
#  'Rockwell',
#  'Segoe UI Symbol',
#  'Rockwell',
#  'Cambria',
#  'FZYaoTi',
#  'Bodoni MT',
#  'Lucida Handwriting',
#  'STXingkai',
#  'Bookman Old Style',
#  'Franklin Gothic Demi Cond',
#  'Lucida Fax',
#  'Malgun Gothic',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Tw Cen MT Condensed',
#  'Lucida Bright',
#  'Tw Cen MT',
#  'Lucida Sans',
#  'Wide Latin',
#  'Forte',
#  'Colonna MT',
#  'Rockwell Condensed',
#  'Candara',
#  'Californian FB',
#  'STHupo',
#  'Bahnschrift',
#  'Eras Medium ITC',
#  'Arial',
#  'Noto Sans CJK TC',
#  'Broadway',
#  'Trebuchet MS',
#  'Vivaldi',
#  'Viner Hand ITC',
#  'Garamond',
#  'Perpetua Titling MT',
#  'Gill Sans MT Condensed',
#  'Nirmala UI',
#  'Edwardian Script ITC',
#  'Baskerville Old Face',
#  'Tempus Sans ITC',
#  'Bodoni MT',
#  'Perpetua',
#  'Bookman Old Style',
#  'Arial',
#  'Onyx',
#  'Agency FB',
#  'Noto Sans CJK TC',
#  'Mongolian Baiti',
#  'Noto Sans CJK TC',
#  'Matura MT Script Capitals',
#  'Monotype Corsiva',
#  'Eras Light ITC',
#  'Gigi',
#  'Garamond',
#  'Bookman Old Style',
#  'Century Gothic',
#  'Arial Rounded MT Bold',
#  'Perpetua',
#  'Gill Sans MT',
#  'Pristina',
#  'Corbel',
#  'Lucida Bright',
#  'Arial',
#  'STZhongsong',
#  'Segoe Print',
#  'Century Gothic',
#  'Rockwell',
#  'Palace Script MT',
#  'Forte',
#  'MS Outlook',
#  'Bodoni MT',
#  'Harrington',
#  'Segoe UI',
#  'Broadway',
#  'Bodoni MT',
#  'Century Schoolbook',
#  'DFKai-SB',
#  'Segoe MDL2 Assets',
#  'Microsoft Yi Baiti',
#  'Lucida Sans',
#  'MS Reference Sans Serif',
#  'FZYaoTi',
#  'Bauhaus 93',
#  'Bodoni MT',
#  'Lucida Handwriting',
#  'Bookman Old Style',
#  'Courier New',
#  'Bodoni MT',
#  'Nirmala UI',
#  'Tw Cen MT',
#  'Consolas',
#  'Niagara Engraved',
#  'Baskerville Old Face',
#  'Perpetua',
#  'Goudy Old Style',
#  'Californian FB',
#  'Matura MT Script Capitals',
#  'Wingdings 3',
#  'Noto Sans Mono CJK TC',
#  'Arial Rounded MT Bold',
#  'Bodoni MT',
#  'Niagara Engraved',
#  'HoloLens MDL2 Assets',
#  'Courier New',
#  'Berlin Sans FB Demi',
#  'Noto Sans CJK TC',
#  'Gill Sans Ultra Bold Condensed',
#  'Tw Cen MT',
#  'Times New Roman',
#  'Garamond',
#  'Comic Sans MS',
#  'Lucida Sans',
#  'MS Reference Sans Serif',
#  'Haettenschweiler',
#  'Niagara Solid',
#  'Bell MT',
#  'Footlight MT Light',
#  'Segoe UI Emoji',
#  'STHupo',
#  'Franklin Gothic Demi',
#  'Franklin Gothic Medium',
#  'Perpetua',
#  'Viner Hand ITC',
#  'STSong',
#  'Lucida Sans Typewriter',
#  'Bell MT',
#  'Lucida Bright',
#  'Noto Sans CJK TC',
#  'Dubai',
#  'Franklin Gothic Heavy',
#  'Comic Sans MS',
#  'STXinwei',
#  'Script MT Bold',
#  'FZShuTi',
#  'Century Schoolbook',
#  'Segoe Marker',
#  'Gadugi',
#  'Century Schoolbook',
#  'Rockwell Condensed',
#  'Magneto',
#  'Agency FB',
#  'Georgia',
#  'Bell MT',
#  'Engravers MT',
#  'Californian FB',
#  'Segoe Script',
#  'Century Gothic',
#  'Showcard Gothic',
#  'Parchment',
#  'Juice ITC',
#  'Impact',
#  'Georgia',
#  'Onyx',
#  'Noto Sans CJK TC',
#  'Maiandra GD',
#  'Arial',
#  'Brush Script MT',
#  'Gill Sans MT Ext Condensed Bold',
#  'Calisto MT',
#  'Dubai',
#  'Noto Sans Mono CJK TC',
#  'Goudy Old Style',
#  'Malgun Gothic',
#  'Gill Sans MT',
#  'Gill Sans MT',
#  'Tw Cen MT',
#  'Calibri',
#  'Marlett',
#  'Poor Richard',
#  'Nirmala UI',
#  'Gill Sans MT Ext Condensed Bold',
#  'Blackadder ITC',
#  'Castellar',
#  'MS Reference Specialty',
#  'Bodoni MT',
#  'Lucida Bright',
#  'Felix Titling',
#  'Arial',
#  'Parchment',
#  'Monotype Corsiva',
#  'Tw Cen MT Condensed Extra Bold',
#  'Playbill',
#  'Tw Cen MT',
#  'Chiller',
#  'Noto Sans CJK TC',
#  'Rockwell Condensed',
#  'Edwardian Script ITC',
#  'Tw Cen MT',
#  'Franklin Gothic Medium',
#  'Gabriola',
#  'Century',
#  'Rockwell Extra Bold',
#  'Lucida Sans Typewriter',
#  'STKaiti',
#  'Tempus Sans ITC',
#  'SketchFlow Print',
#  'FZShuTi',
#  'Lucida Sans',
#  'Brush Script MT',
#  'Georgia',
#  'Candara',
#  'Bradley Hand ITC',
#  'Trebuchet MS',
#  'Kunstler Script',
#  'Candara',
#  'Ebrima',
#  'Centaur',
#  'Gigi',
#  'Dubai',
#  'Calisto MT',
#  'Segoe UI',
#  'Arial',
#  'Microsoft New Tai Lue',
#  'Papyrus',
#  'Colonna MT',
#  'Blackadder ITC',
#  'Perpetua Titling MT',
#  'Segoe UI',
#  'High Tower Text',
#  'Consolas',
#  'Tw Cen MT Condensed Extra Bold',
#  'Elephant',
#  'Bookman Old Style',
#  'Century Schoolbook',
#  'Lucida Sans Typewriter',
#  'Tw Cen MT Condensed',
#  'Vivaldi',
#  'Myanmar Text',
#  'Perpetua',
#  'Franklin Gothic Book',
#  'Book Antiqua',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'Century Schoolbook',
#  'YouYuan',
#  'Niagara Solid',
#  'Ravie',
#  'Calisto MT',
#  'Ravie',
#  'Century Gothic',
#  'Lucida Calligraphy',
#  'MS Outlook',
#  'STFangsong',
#  'Gill Sans MT',
#  'Lucida Sans',
#  'Microsoft Himalaya',
#  'Book Antiqua',
#  'Noto Sans CJK TC',
#  'Constantia',
#  'Times New Roman',
#  'Trebuchet MS',
#  'Script MT Bold',
#  'Footlight MT Light',
#  'Goudy Stout',
#  'Garamond',
#  'Verdana',
#  'Arial',
#  'STXingkai',
#  'OCR A Extended',
#  'Rockwell',
#  'Britannic Bold',
#  'Courier New',
#  'Arial',
#  'Lucida Sans',
#  'Dubai',
#  'Chiller',
#  'Microsoft PhagsPa',
#  'Lucida Sans Typewriter',
#  'Noto Sans CJK TC',
#  'Times New Roman',
#  'Noto Sans Mono CJK TC',
#  'Goudy Old Style',
#  'Book Antiqua',
#  'Leelawadee UI',
#  'Leelawadee UI',
#  'Rockwell',
#  'Castellar',
#  'Noto Sans CJK TC',
#  'Vladimir Script',
#  'Eras Light ITC',
#  'Rockwell',
#  'Wingdings 2',
#  'Perpetua Titling MT',
#  'Calisto MT',
#  'Georgia',
#  'Dubai',
#  'Ink Free',
#  'Berlin Sans FB Demi',
#  'Maiandra GD',
#  'Candara',
#  'Verdana',
#  'Franklin Gothic Demi Cond',
#  'Gill Sans MT',
#  'STXihei',
#  'Bodoni MT',
#  'Arial',
#  'STCaiyun',
#  'Rockwell Condensed',
#  'Century Gothic',
#  'Lucida Fax',
#  'Wingdings 3',
#  'Rockwell',
#  'Dubai',
#  'Elephant',
#  'Noto Sans CJK TC',
#  'Noto Sans CJK TC',
#  'MT Extra',
#  'Showcard Gothic',
#  'Consolas',
#  'MS Reference Specialty',
#  'Noto Sans CJK TC',
#  'Noto Sans CJK TC',
#  'Bookman Old Style',
#  'High Tower Text',
#  'Courier New',
#  'Bookshelf Symbol 7',
#  'Book Antiqua',
#  'Lucida Sans Typewriter',
#  'Old English Text MT',
#  'Garamond',
#  'YouYuan',
#  'Arial',
#  'Goudy Old Style',
#  'Bodoni MT',
#  'Segoe UI',
#  'Agency FB',
#  'Berlin Sans FB',
#  'Nirmala UI',
#  'Noto Sans Mono CJK TC',
#  'Elephant',
#  'Nirmala UI',
#  'Freestyle Script',
#  'Century Gothic',
#  'Poor Richard',
#  'Bodoni MT',
#  'LiSu',
#  'Eras Bold ITC',
#  'Mistral',
#  'Century',
#  'Eras Demi ITC',
#  'Candara',
#  'Calibri',
#  'STZhongsong',
#  'Candara',
#  'Stencil',
#  'Leelawadee UI',
#  'Wingdings 2',
#  'Californian FB',
#  'Century Schoolbook',
#  'Century Gothic',
#  'Playbill',
#  'Bodoni MT',
#  'Gloucester MT Extra Condensed',
#  'Buxton Sketch',
#  'LiSu',
#  'Microsoft Sans Serif',
#  'Curlz MT',
#  'OCR A Extended',
#  'Gill Sans MT Condensed',
#  'Lucida Bright',
#  'Rockwell Extra Bold',
#  'STSong',
#  'Kunstler Script',
#  'Bookman Old Style',
#  'Harrington',
#  'Bauhaus 93',
#  'Noto Sans CJK TC',
#  'Lucida Fax',
#  'Nirmala UI',
#  'Palace Script MT',
#  'Elephant',
#  'Jokerman',
#  'Engravers MT',
#  'Centaur',
#  'Buxton Sketch',
#  'Webdings',
#  'Copperplate Gothic Bold',
#  'Candara',
#  'Harlow Solid Italic',
#  'Franklin Gothic Book',
#  'STFangsong',
#  'Rockwell',
#  'Berlin Sans FB',
#  'Franklin Gothic Medium Cond',
#  'Gill Sans Ultra Bold',
#  'Garamond',
#  'Noto Sans Mono CJK TC',
#  'Lucida Bright',
#  'Cooper Black',
#  'Book Antiqua',
#  'Franklin Gothic Demi',
#  'High Tower Text',
#  'Perpetua',
#  'Snap ITC',
#  'Calisto MT',
#  'Book Antiqua',
#  'Copperplate Gothic Bold',
#  'Bell MT',
#  'Franklin Gothic Demi',
#  'Perpetua',
#  'Franklin Gothic Book',
#  'Noto Sans CJK TC',
#  'Gill Sans Ultra Bold Condensed',
#  'Mistral',
#  'Bradley Hand ITC',
#  'Gill Sans MT',
#  'Rage Italic',
#  'Pristina',
#  'Bodoni MT',
#  'Noto Sans Mono CJK TC',
#  'STCaiyun',
#  'Bernard MT Condensed',
#  'Franklin Gothic Demi',
#  'Tw Cen MT',
#  'Lucida Fax',
#  'Tw Cen MT',
#  'Perpetua',
#  'Dubai',
#  'Franklin Gothic Heavy']

# %% [markdown]
# ## 05-01 暖身來個比較「正規」的資料
#
# ### 一些 Open Data
#
# * [政府資料開放平台](https://data.gov.tw)
# * [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php)

# %%
df = pd.read_csv('http://stats.moe.gov.tw/files/detail/107/107_student.csv')

# %%
df.head()
# Out:
#              大專校院校別學生數 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  107 學年度 SY2018-2019        NaN        NaN        NaN        NaN        NaN
# 1                 學校代碼       學校名稱     日間∕進修別        等級別         總計        男生計
# 2                 0001     國立政治大學        D 日       D 博士        965        551
# 3                 0001     國立政治大學        D 日       M 碩士      3,998      1,854
# 4                 0001     國立政治大學        D 日       B 學士      9,630      3,983
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 15  \
# 0        NaN        NaN        NaN        NaN     ...             NaN
# 1        女生計      一年級男生      一年級女生      二年級男生     ...           五年級男生
# 2        414         96         85         82     ...              71
# 3      2,144        624        742        632     ...               -
# 4      5,647        899      1,287        890     ...               -
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1       五年級女生       六年級男生       六年級女生       七年級男生       七年級女生       延修生男生
# 2          52          58          46          74          40           -
# 3           -           -           -           -           -           -
# 4           -           -           -           -           -         326
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0         NaN         NaN         NaN
# 1       延修生女生        縣市名稱         體系別
# 2           -      30 臺北市        1 一般
# 3           -      30 臺北市        1 一般
# 4         463      30 臺北市        1 一般
#
# [5 rows x 25 columns]

# %%
df.loc[1]#第一列
# Out:
# 大專校院校別學生數        學校代碼
# Unnamed: 1       學校名稱
# Unnamed: 2     日間∕進修別
# Unnamed: 3        等級別
# Unnamed: 4         總計
# Unnamed: 5        男生計
# Unnamed: 6        女生計
# Unnamed: 7      一年級男生
# Unnamed: 8      一年級女生
# Unnamed: 9      二年級男生
# Unnamed: 10     二年級女生
# Unnamed: 11     三年級男生
# Unnamed: 12     三年級女生
# Unnamed: 13     四年級男生
# Unnamed: 14     四年級女生
# Unnamed: 15     五年級男生
# Unnamed: 16     五年級女生
# Unnamed: 17     六年級男生
# Unnamed: 18     六年級女生
# Unnamed: 19     七年級男生
# Unnamed: 20     七年級女生
# Unnamed: 21     延修生男生
# Unnamed: 22     延修生女生
# Unnamed: 23      縣市名稱
# Unnamed: 24       體系別
# Name: 1, dtype: object

# %%
colnames = df.loc[1].values
colnames
# Out:
# array(['學校代碼', '學校名稱', '日間∕進修別', '等級別', '總計', '男生計', '女生計', '一年級男生',
#        '一年級女生', '二年級男生', '二年級女生', '三年級男生', '三年級女生', '四年級男生', '四年級女生',
#        '五年級男生', '五年級女生', '六年級男生', '六年級女生', '七年級男生', '七年級女生', '延修生男生',
#        '延修生女生', '縣市名稱', '體系別'], dtype=object)

# %%
df = df[2:]#注意看上面的資料是第二列開始才有用

# %%
df.head()#由於上面一行已經篩選掉第二列以前的 所以這裏只剩下政治大學開始
# Out:
#   大專校院校別學生數 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 2      0001     國立政治大學        D 日       D 博士        965        551        414
# 3      0001     國立政治大學        D 日       M 碩士      3,998      1,854      2,144
# 4      0001     國立政治大學        D 日       B 學士      9,630      3,983      5,647
# 5      0001     國立政治大學        N 職       M 碩士      1,750        896        854
# 6      0002     國立清華大學        D 日       D 博士      1,664      1,221        443
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 15 Unnamed: 16  \
# 2         96         85         82     ...              71          52
# 3        624        742        632     ...               -           -
# 4        899      1,287        890     ...               -           -
# 5        303        248        253     ...              53          47
# 6        225         99        201     ...             158          50
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 2          58          46          74          40           -           -
# 3           -           -           -           -           -           -
# 4           -           -           -           -         326         463
# 5           -           -           -           -           -           -
# 6         112          43         168          58           -           -
#
#   Unnamed: 23 Unnamed: 24
# 2      30 臺北市        1 一般
# 3      30 臺北市        1 一般
# 4      30 臺北市        1 一般
# 5      30 臺北市        1 一般
# 6      18 新竹市        1 一般
#
# [5 rows x 25 columns]

# %%
df.columns = colnames #因為剛剛的colnames是第一列的圖例，所以這裡只是把它放去圖表上的真正正確位置(自己和上面的圖比對一下)

# %%
df.head()
# Out:
#    學校代碼    學校名稱 日間∕進修別   等級別     總計    男生計    女生計 一年級男生  一年級女生 二年級男生  ...   \
# 2  0001  國立政治大學    D 日  D 博士    965    551    414    96     85    82  ...
# 3  0001  國立政治大學    D 日  M 碩士  3,998  1,854  2,144   624    742   632  ...
# 4  0001  國立政治大學    D 日  B 學士  9,630  3,983  5,647   899  1,287   890  ...
# 5  0001  國立政治大學    N 職  M 碩士  1,750    896    854   303    248   253  ...
# 6  0002  國立清華大學    D 日  D 博士  1,664  1,221    443   225     99   201  ...
#
#   五年級男生 五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別
# 2    71    52    58    46    74    40     -     -  30 臺北市  1 一般
# 3     -     -     -     -     -     -     -     -  30 臺北市  1 一般
# 4     -     -     -     -     -     -   326   463  30 臺北市  1 一般
# 5    53    47     -     -     -     -     -     -  30 臺北市  1 一般
# 6   158    50   112    43   168    58     -     -  18 新竹市  1 一般
#
# [5 rows x 25 columns]

# %%
(df['日間∕進修別'] == 'D 日') & (df['等級別'] == 'B 學士') #又是日間部又是大學部的
# Out:
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
# 30      True
# 31     False
#        ...
# 784    False
# 785    False
# 786    False
# 787    False
# 788     True
# 789    False
# 790    False
# 791     True
# 792    False
# 793    False
# 794    False
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# 800    False
# 801    False
# 802    False
# 803    False
# 804    False
# 805    False
# 806    False
# 807    False
# 808    False
# 809    False
# 810    False
# 811    False
# 812     True
# 813    False
# Length: 812, dtype: bool

# %%
df[(df['日間∕進修別'] == 'D 日') & (df['等級別'] == 'B 學士')] #又是日間部又是大學部的
# Out:
#      學校代碼       學校名稱 日間∕進修別   等級別      總計    男生計     女生計  一年級男生  一年級女生  二年級男生  \
# 4    0001     國立政治大學    D 日  B 學士   9,630  3,983   5,647    899  1,287    890
# 8    0002     國立清華大學    D 日  B 學士   8,689  4,696   3,993  1,089    865  1,087
# 13   0003     國立臺灣大學    D 日  B 學士  16,604  9,447   7,157  2,126  1,525  2,110
# 17   0004   國立臺灣師範大學    D 日  B 學士   8,079  3,583   4,496    846  1,066    850
# 21   0005     國立成功大學    D 日  B 學士  11,390  7,123   4,267  1,672  1,010  1,651
# 25   0006     國立中興大學    D 日  B 學士   8,090  4,685   3,405  1,087    799  1,100
# 30   0007     國立交通大學    D 日  B 學士   5,398  3,735   1,663    881    417    907
# 34   0008     國立中央大學    D 日  B 學士   6,057  3,872   2,185    931    558    956
# 38   0009     國立中山大學    D 日  B 學士   4,726  2,953   1,773    694    412    720
# 42   0012   國立臺灣海洋大學    D 日  B 學士   5,769  4,002   1,767    956    455    955
# 48   0013     國立中正大學    D 日  B 學士   6,579  3,591   2,988    814    727    851
# 52   0014   國立高雄師範大學    D 日  B 學士   3,492  1,676   1,816    452    442    368
# 56   0015   國立彰化師範大學    D 日  B 學士   4,924  2,587   2,337    621    569    618
# 60   0016     國立陽明大學    D 日  B 學士   2,084  1,167     917    229    176    211
# 64   0017     國立臺北大學    D 日  B 學士   5,822  2,655   3,167    617    769    633
# 69   0018     國立嘉義大學    D 日  B 學士   7,674  3,928   3,746    927    917    934
# 74   0019     國立高雄大學    D 日  B 學士   4,277  2,465   1,812    634    451    559
# 79   0020     國立東華大學    D 日  B 學士   7,531  3,616   3,915    824    963    863
# 83   0021   國立暨南國際大學    D 日  B 學士   4,599  2,102   2,497    446    600    519
# 114  0028   國立臺北藝術大學    D 日  B 學士   1,713    596   1,117    128    244    149
# 120  0029   國立臺灣藝術大學    D 日  B 學士   2,459    707   1,752    155    376    140
# 126  0030     國立臺東大學    D 日  B 學士   3,473  1,705   1,768    425    456    422
# 132  0031     國立宜蘭大學    D 日  B 學士   4,409  2,865   1,544    649    399    731
# 137  0032     國立聯合大學    D 日  B 學士   5,901  4,022   1,879    963    460    983
# 150  0035   國立臺南藝術大學    D 日  B 學士     774    240     534     57    132     55
# 155  0036     國立臺南大學    D 日  B 學士   3,885  1,820   2,065    435    497    429
# 160  0037   國立臺北教育大學    D 日  B 學士   3,408  1,174   2,234    270    566    288
# 164  0039   國立臺中教育大學    D 日  B 學士   3,275  1,171   2,104    282    513    296
# 180  0044     國立體育大學    D 日  B 學士   1,675  1,075     600    272    140    235
# 200  0048     國立金門大學    D 日  B 學士   3,153  1,593   1,560    335    377    394
# ..    ...        ...    ...   ...     ...    ...     ...    ...    ...    ...
# 290  1009       長庚大學    D 日  B 學士   5,260  2,652   2,608    557    615    562
# 294  1010       元智大學    D 日  B 學士   7,113  4,053   3,060    950    733    953
# 298  1011       中華大學    D 日  B 學士   5,020  3,121   1,899    767    452    502
# 304  1012       大葉大學    D 日  B 學士   8,019  4,191   3,828    892    882    916
# 310  1013       華梵大學    D 日  B 學士   1,447    788     659    166    139    104
# 314  1014       義守大學    D 日  B 學士  12,546  6,278   6,268  1,469  1,609  1,425
# 320  1015       世新大學    D 日  B 學士   9,671  3,409   6,262    823  1,489    770
# 326  1016       銘傳大學    D 日  B 學士  17,333  6,868  10,465  1,664  2,520  1,531
# 330  1017       實踐大學    D 日  B 學士  11,258  3,713   7,545    807  1,903    813
# 342  1019     高雄醫學大學    D 日  B 學士   5,546  2,445   3,101    481    738    498
# 347  1020       南華大學    D 日  B 學士   4,489  2,160   2,329    647    701    453
# 351  1021       真理大學    D 日  B 學士   5,830  2,834   2,996    676    846    570
# 356  1022       大同大學    D 日  B 學士   3,689  2,226   1,463    535    353    494
# 389  1027       慈濟大學    D 日  B 學士   2,968  1,148   1,820    264    435    223
# 393  1028     臺北醫學大學    D 日  B 學士   4,733  1,986   2,747    357    575    387
# 399  1029     中山醫學大學    D 日  B 學士   6,099  2,355   3,744    461    875    422
# 427  1033       長榮大學    D 日  B 學士   8,210  3,594   4,616    766  1,206    781
# 441  1035     中國醫藥大學    D 日  B 學士   6,420  2,866   3,554    515    725    519
# 466  1039       玄奘大學    D 日  B 學士   2,859  1,186   1,673    194    334    251
# 518  1048       亞洲大學    D 日  B 學士   9,616  3,524   6,092    825  1,509    804
# 522  1049       開南大學    D 日  B 學士   5,119  2,508   2,611    583    550    499
# 527  1050       佛光大學    D 日  B 學士   2,970  1,380   1,590    320    425    322
# 576  1058       明道大學    D 日  B 學士   2,819  1,608   1,211    385    272    275
# 625  1067     台灣首府大學    D 日  B 學士   1,758    877     881    220    208    154
# 697  1079       康寧大學    D 日  B 學士     607    287     320     30     85     66
# 730  1125   中信金融管理學院    D 日  B 學士     588    292     296    113     84     53
# 755  1176  稻江科技暨管理學院    D 日  B 學士   1,455    773     682    231    229    228
# 788  1195      馬偕醫學院    D 日  B 學士     661    254     407     48    111     40
# 791  1196     法鼓文理學院    D 日  B 學士      57     21      36      4     11      7
# 812  3002     臺北市立大學    D 日  B 學士   5,304   2373   2,931    566    725    524
#
#      ...  五年級男生 五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別
# 4    ...      -     -     -     -     -     -   326   463  30 臺北市  1 一般
# 8    ...      -     -     -     -     -     -   286   166  18 新竹市  1 一般
# 13   ...    184    98   126    61   102    35   671   537  30 臺北市  1 一般
# 17   ...      -     -     -     -     -     -   240   271  30 臺北市  3 師範
# 21   ...     82    68    49    27    53    21   355   149  21 臺南市  1 一般
# 25   ...     21    45     -     -     -     -   205    93  19 臺中市  1 一般
# 30   ...      -     -     -     -     -     -   148    60  18 新竹市  1 一般
# 34   ...      -     -     -     -     -     -   161    56  03 桃園市  1 一般
# 38   ...      -     -     -     -     -     -   179    83  50 高雄市  1 一般
# 42   ...      -     -     -     -     -     -   194    31  17 基隆市  1 一般
# 48   ...      -     -     -     -     -     -   165    84  10 嘉義縣  1 一般
# 52   ...      -     -     -     -     -     -    51    42  50 高雄市  3 師範
# 56   ...      -     -     -     -     -     -   135    54  07 彰化縣  3 師範
# 60   ...    109    64   103    67    81    45    18    14  30 臺北市  1 一般
# 64   ...      -     -     -     -     -     -   124   133  01 新北市  1 一般
# 69   ...     31    21     -     -     -     -   129    80  20 嘉義市  1 一般
# 74   ...      -     -     -     -     -     -   122    59  50 高雄市  1 一般
# 79   ...      -     -     -     -     -     -   260   167  15 花蓮縣  1 一般
# 83   ...      -     -     -     -     -     -   110    92  08 南投縣  1 一般
# 114  ...      -     -     -     -     -     -    64   121  30 臺北市  1 一般
# 120  ...      -     -     -     -     -     -   114   190  01 新北市  1 一般
# 126  ...      -     -     -     -     -     -    80    48  14 臺東縣  1 一般
# 132  ...      -     -     -     -     -     -   110    25  02 宜蘭縣  1 一般
# 137  ...     23    18     -     -     -     -   166    35  05 苗栗縣  1 一般
# 150  ...      -     -     -     -     -     -    23    24  11 臺南市  1 一般
# 155  ...      -     -     -     -     -     -    92    48  21 臺南市  1 一般
# 160  ...      -     -     -     -     -     -    79    79  30 臺北市  3 師範
# 164  ...      -     -     -     -     -     -    55    49  19 臺中市  3 師範
# 180  ...      -     -     -     -     -     -    94    31  03 桃園市  1 一般
# 200  ...     25    16     -     -     -     -    82    38  71 金門縣  1 一般
# ..   ...    ...   ...   ...   ...   ...   ...   ...   ...     ...   ...
# 290  ...     98    55    92    64   110    45   119    78  03 桃園市  1 一般
# 294  ...      -     -     -     -     -     -   235    98  03 桃園市  1 一般
# 298  ...     21    20     -     -     -     -   280    87  18 新竹市  1 一般
# 304  ...      -     -     -     -     -     -   233   127  07 彰化縣  1 一般
# 310  ...      -     -     -     -     -     -    91    34  01 新北市  1 一般
# 314  ...     23    28     -     -     -     -   417   208  12 高雄市  1 一般
# 320  ...      -     -     -     -     -     -   210   189  30 臺北市  1 一般
# 326  ...     37    20     -     -     -     -   489   433  30 臺北市  1 一般
# 330  ...     16    20     -     -     -     -   261   292  30 臺北市  1 一般
# 342  ...    183   110   166    84   100    46    65    45  50 高雄市  1 一般
# 347  ...      -     -     -     -     -     -   164    60  10 嘉義縣  1 一般
# 351  ...      -     -     -     -     -     -   239   112  01 新北市  1 一般
# 356  ...      -     -     -     -     -     -   159    43  30 臺北市  1 一般
# 389  ...     48    51    31    25    23    34    60    61  15 花蓮縣  1 一般
# 393  ...    170   134   158   118    93    69    45    75  30 臺北市  1 一般
# 399  ...    155    70   142    72   103    39    69    69  19 臺中市  1 一般
# 427  ...      -     -     -     -     -     -   242   135  11 臺南市  1 一般
# 441  ...    342   306   171   140   172   126    69    65  19 臺中市  1 一般
# 466  ...      -     -     -     -     -     -   119    62  18 新竹市  1 一般
# 518  ...      -     -     -     -     -     -   198   137  06 臺中市  1 一般
# 522  ...      -     -     -     -     -     -   230   160  03 桃園市  1 一般
# 527  ...      -     -     -     -     -     -    73    66  02 宜蘭縣  1 一般
# 576  ...      -     -     -     -     -     -    85    20  07 彰化縣  1 一般
# 625  ...      -     -     -     -     -     -    81    46  11 臺南市  1 一般
# 697  ...      -     -     -     -     -     -    41     9  30 臺北市  1 一般
# 730  ...      -     -     -     -     -     -     -     -  21 臺南市  1 一般
# 755  ...      -     -     -     -     -     -    18     9  10 嘉義縣  1 一般
# 788  ...     19    23    33    14    19    22     5     3  01 新北市  1 一般
# 791  ...      -     -     -     -     -     -     -     -  01 新北市  1 一般
# 812  ...      -     -     -     -     -     -   165   139  30 臺北市  1 一般
#
# [70 rows x 25 columns]

# %%
undergraduate = df[(df['日間∕進修別'] == 'D 日') & (df['等級別'] == 'B 學士')] #又是日間部又是大學部的

# %%
undergraduate.head()
# Out:
#     學校代碼      學校名稱 日間∕進修別   等級別      總計    男生計    女生計  一年級男生  一年級女生  二年級男生  \
# 4   0001    國立政治大學    D 日  B 學士   9,630  3,983  5,647    899  1,287    890
# 8   0002    國立清華大學    D 日  B 學士   8,689  4,696  3,993  1,089    865  1,087
# 13  0003    國立臺灣大學    D 日  B 學士  16,604  9,447  7,157  2,126  1,525  2,110
# 17  0004  國立臺灣師範大學    D 日  B 學士   8,079  3,583  4,496    846  1,066    850
# 21  0005    國立成功大學    D 日  B 學士  11,390  7,123  4,267  1,672  1,010  1,651
#
#     ...  五年級男生 五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別
# 4   ...      -     -     -     -     -     -   326   463  30 臺北市  1 一般
# 8   ...      -     -     -     -     -     -   286   166  18 新竹市  1 一般
# 13  ...    184    98   126    61   102    35   671   537  30 臺北市  1 一般
# 17  ...      -     -     -     -     -     -   240   271  30 臺北市  3 師範
# 21  ...     82    68    49    27    53    21   355   149  21 臺南市  1 一般
#
# [5 rows x 25 columns]

# %% [markdown]
# ![view 和 copy](images/pandas_view_copy.png)
#
# 注意接下來我們用了 `copy`, 你可能感覺好像不需要用, 事實上沒有用也可以執行, 只是 `pandas` 會警告你...
#
# 這牽涉大概每個用 `pandas` 的人, 都會碰到的 SettingWithCopyWarning!
#
# 請參考[這個影片](https://youtu.be/4R4WsDJ-KVc), 理解要怎麼解決。事實上這是一個非常棒的 `pandas` 系列教學!

# %%
undergraduate.loc[:,'學校名稱':'女生計']#每一列都要  行: 從學校名稱到一年級女生
# Out:
#           學校名稱 日間∕進修別   等級別      總計    男生計     女生計
# 4       國立政治大學    D 日  B 學士   9,630  3,983   5,647
# 8       國立清華大學    D 日  B 學士   8,689  4,696   3,993
# 13      國立臺灣大學    D 日  B 學士  16,604  9,447   7,157
# 17    國立臺灣師範大學    D 日  B 學士   8,079  3,583   4,496
# 21      國立成功大學    D 日  B 學士  11,390  7,123   4,267
# 25      國立中興大學    D 日  B 學士   8,090  4,685   3,405
# 30      國立交通大學    D 日  B 學士   5,398  3,735   1,663
# 34      國立中央大學    D 日  B 學士   6,057  3,872   2,185
# 38      國立中山大學    D 日  B 學士   4,726  2,953   1,773
# 42    國立臺灣海洋大學    D 日  B 學士   5,769  4,002   1,767
# 48      國立中正大學    D 日  B 學士   6,579  3,591   2,988
# 52    國立高雄師範大學    D 日  B 學士   3,492  1,676   1,816
# 56    國立彰化師範大學    D 日  B 學士   4,924  2,587   2,337
# 60      國立陽明大學    D 日  B 學士   2,084  1,167     917
# 64      國立臺北大學    D 日  B 學士   5,822  2,655   3,167
# 69      國立嘉義大學    D 日  B 學士   7,674  3,928   3,746
# 74      國立高雄大學    D 日  B 學士   4,277  2,465   1,812
# 79      國立東華大學    D 日  B 學士   7,531  3,616   3,915
# 83    國立暨南國際大學    D 日  B 學士   4,599  2,102   2,497
# 114   國立臺北藝術大學    D 日  B 學士   1,713    596   1,117
# 120   國立臺灣藝術大學    D 日  B 學士   2,459    707   1,752
# 126     國立臺東大學    D 日  B 學士   3,473  1,705   1,768
# 132     國立宜蘭大學    D 日  B 學士   4,409  2,865   1,544
# 137     國立聯合大學    D 日  B 學士   5,901  4,022   1,879
# 150   國立臺南藝術大學    D 日  B 學士     774    240     534
# 155     國立臺南大學    D 日  B 學士   3,885  1,820   2,065
# 160   國立臺北教育大學    D 日  B 學士   3,408  1,174   2,234
# 164   國立臺中教育大學    D 日  B 學士   3,275  1,171   2,104
# 180     國立體育大學    D 日  B 學士   1,675  1,075     600
# 200     國立金門大學    D 日  B 學士   3,153  1,593   1,560
# ..         ...    ...   ...     ...    ...     ...
# 290       長庚大學    D 日  B 學士   5,260  2,652   2,608
# 294       元智大學    D 日  B 學士   7,113  4,053   3,060
# 298       中華大學    D 日  B 學士   5,020  3,121   1,899
# 304       大葉大學    D 日  B 學士   8,019  4,191   3,828
# 310       華梵大學    D 日  B 學士   1,447    788     659
# 314       義守大學    D 日  B 學士  12,546  6,278   6,268
# 320       世新大學    D 日  B 學士   9,671  3,409   6,262
# 326       銘傳大學    D 日  B 學士  17,333  6,868  10,465
# 330       實踐大學    D 日  B 學士  11,258  3,713   7,545
# 342     高雄醫學大學    D 日  B 學士   5,546  2,445   3,101
# 347       南華大學    D 日  B 學士   4,489  2,160   2,329
# 351       真理大學    D 日  B 學士   5,830  2,834   2,996
# 356       大同大學    D 日  B 學士   3,689  2,226   1,463
# 389       慈濟大學    D 日  B 學士   2,968  1,148   1,820
# 393     臺北醫學大學    D 日  B 學士   4,733  1,986   2,747
# 399     中山醫學大學    D 日  B 學士   6,099  2,355   3,744
# 427       長榮大學    D 日  B 學士   8,210  3,594   4,616
# 441     中國醫藥大學    D 日  B 學士   6,420  2,866   3,554
# 466       玄奘大學    D 日  B 學士   2,859  1,186   1,673
# 518       亞洲大學    D 日  B 學士   9,616  3,524   6,092
# 522       開南大學    D 日  B 學士   5,119  2,508   2,611
# 527       佛光大學    D 日  B 學士   2,970  1,380   1,590
# 576       明道大學    D 日  B 學士   2,819  1,608   1,211
# 625     台灣首府大學    D 日  B 學士   1,758    877     881
# 697       康寧大學    D 日  B 學士     607    287     320
# 730   中信金融管理學院    D 日  B 學士     588    292     296
# 755  稻江科技暨管理學院    D 日  B 學士   1,455    773     682
# 788      馬偕醫學院    D 日  B 學士     661    254     407
# 791     法鼓文理學院    D 日  B 學士      57     21      36
# 812     臺北市立大學    D 日  B 學士   5,304   2373   2,931
#
# [70 rows x 6 columns]

# %%
df2 = undergraduate.loc[:,'學校名稱':'女生計'].copy() # copy 一份

# %%
df2.head()
# Out:
#         學校名稱 日間∕進修別   等級別      總計    男生計    女生計
# 4     國立政治大學    D 日  B 學士   9,630  3,983  5,647
# 8     國立清華大學    D 日  B 學士   8,689  4,696  3,993
# 13    國立臺灣大學    D 日  B 學士  16,604  9,447  7,157
# 17  國立臺灣師範大學    D 日  B 學士   8,079  3,583  4,496
# 21    國立成功大學    D 日  B 學士  11,390  7,123  4,267

# %%
df2.女生計/df2.男生計 # 印出df2.男生計發現entry中有","(如上圖)，所以要先把它變為數字才能除
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1029             with np.errstate(all='ignore'):
# -> 1030                 return na_op(lvalues, rvalues)
#    1031         except Exception:
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1014                 mask = notna(x) & notna(y)
# -> 1015                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1016             else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-280654e1d6ac> in <module>()
# ----> 1 df2.女生計/df2.男生計 # 印出df2.男生計發現entry中有","(如上圖)，所以要先把它變為數字才能除
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1064             rvalues = rvalues.values
#    1065
# -> 1066         result = safe_na_op(lvalues, rvalues)
#    1067         return construct_result(left, result,
#    1068                                 index=left.index, name=res_name, dtype=None)
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1032             if is_object_dtype(lvalues):
#    1033                 return libalgos.arrmap_object(lvalues,
# -> 1034                                               lambda x: op(x, rvalues))
#    1035             raise
#    1036
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1032             if is_object_dtype(lvalues):
#    1033                 return libalgos.arrmap_object(lvalues,
# -> 1034                                               lambda x: op(x, rvalues))
#    1035             raise
#    1036
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
import locale
#為了用atof

# %%
locale.setlocale(locale.LC_NUMERIC,'')
# Out:
# 'Chinese (Traditional)_Taiwan.950'

# %%
df2['男生計'] = df2['男生計'].apply(locale.atof)

# %%
df2['女生計']=df2['女生計'].apply(locale.atof)

# %%
df2['女男比例'] = df2.女生計 / df2.男生計   #新增一行叫女男比例
df2.head()
# Out:
#         學校名稱 日間∕進修別   等級別      總計     男生計     女生計      女男比例
# 4     國立政治大學    D 日  B 學士   9,630  3983.0  5647.0  1.417776
# 8     國立清華大學    D 日  B 學士   8,689  4696.0  3993.0  0.850298
# 13    國立臺灣大學    D 日  B 學士  16,604  9447.0  7157.0  0.757595
# 17  國立臺灣師範大學    D 日  B 學士   8,079  3583.0  4496.0  1.254814
# 21    國立成功大學    D 日  B 學士  11,390  7123.0  4267.0  0.599045

# %%
df3 = df2.sort_values(by= ['女男比例'],ascending=False) # ascending =False表示從高排到低

# %%
df3[:20].plot.bar(x='學校名稱',y=['女男比例']);

# %% [markdown]
# ## 05-02 例子、例子、例子

# %% [markdown]
# ### 我的 Mac 有沒有好棒棒

# %%
df = pd.read_html('https://browser.geekbench.com/mac-benchmarks')

# %%
len(df)#df[0]~df[1]
# Out:
# 2

# %%
mac = df[0]

# %%
mac.head()
# Out:
#                                                  Mac  Score  Unnamed: 2
# 0  iMac (27-inch Retina Mid 2017) Intel Core i7-7...   5684         NaN
# 1  Mac mini (Late 2018) Intel Core i7-8700B @ 3.2...   5659         NaN
# 2  MacBook Pro (15-inch Mid 2018) Intel Core i9-8...   5347         NaN
# 3  iMac Pro (Late 2017) Intel Xeon W-2150B @ 3.0 ...   5321         NaN
# 4  iMac (27-inch Retina Late 2015) Intel Core i7-...   5282         NaN

# %%
mac.Mac.str.contains('Mid 2018')#第一行的Mac中的字串(Str)是否含Mid 2018
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13      True
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# 261    False
# Name: Mac, Length: 262, dtype: bool

# %%
mac[mac.Mac.str.contains('Mid 2018')]#第一行的Mac
# Out:
#                                                   Mac  Score  Unnamed: 2
# 2   MacBook Pro (15-inch Mid 2018) Intel Core i9-8...   5347         NaN
# 10  MacBook Pro (13-inch Mid 2018) Intel Core i7-8...   5138         NaN
# 13  MacBook Pro (15-inch Mid 2018) Intel Core i7-8...   5053         NaN
# 14  MacBook Pro (15-inch Mid 2018) Intel Core i7-8...   4926         NaN
# 22  MacBook Pro (13-inch Mid 2018) Intel Core i5-8...   4523         NaN

# %%
mac[mac.Score>5347]
# Out:
#                                                  Mac  Score  Unnamed: 2
# 0  iMac (27-inch Retina Mid 2017) Intel Core i7-7...   5684         NaN
# 1  Mac mini (Late 2018) Intel Core i7-8700B @ 3.2...   5659         NaN

# %% [markdown]
# ### 大樂透

# %%
df=pd.read_html('http://www.9800.com.tw/statistics.asp')

# %%
len(df)
# Out:
# 7

# %%
df_lot =df[3]#要反覆測試到找到自己要的

# %%
colnames = df_lot.loc[1].values
df_lot.loc[1].values
# Out:
# array(['期次', '開獎日期', '球號', '特號', '單雙', '和值', '均值', '同尾', '連號', '首尾差',
#        '尾數和', '首數和', nan, nan, nan, nan, nan], dtype=object)

# %%
df_lot = df_lot.loc[2:]#先印出df_lot.head()觀察我們要的數據從哪裡開始

# %%
df_lot.columns = colnames

# %%
df_lot.head()
# Out:
#        期次        開獎日期  球號  特號  單雙  和值  均值  同尾  連號  首尾差  尾數和 首數和           NaN  \
# 2  108011  2019-02-02  02  07  22  35  46  49  41  3:3  161  26         2尾(2)
# 3  108012  2019-02-03  12  24  28  36  37  40   6  1:5  177  29           NaN
# 4  108013  2019-02-04  06  08  24  32  34  36  49  0:6  140  23  4尾(2), 6尾(2)
# 5  108014  2019-02-05  13  18  30  34  45  49  33  3:3  189  31           NaN
# 6  108015  2019-02-06  17  23  28  29  32  39  12  4:2  168  28         9尾(2)
#
#     NaN   NaN   NaN   NaN
# 2   NaN  47.0  31.0  13.0
# 3  3637  28.0  27.0  15.0
# 4   NaN  30.0  30.0  11.0
# 5   NaN  36.0  29.0  16.0
# 6  2829  22.0  38.0  13.0

# %% [markdown]
# ## 05-03 正式開始
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv('dataset/grades.csv')

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。
#
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 05-04 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df['國文' ]# df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
# 5     13
# 6     11
# 7      8
# 8      9
# 9     10
# 10    14
# 11    13
# 12    11
# 13    15
# 14     8
# 15    11
# 16    14
# 17    12
# 18     9
# 19    14
# 20    13
# 21     9
# 22    12
# 23    10
# 24    10
# 25    13
# 26    13
# 27     8
# 28    15
# 29    14
#       ..
# 70     9
# 71     9
# 72    10
# 73    13
# 74    14
# 75    13
# 76     9
# 77    13
# 78    12
# 79     9
# 80    13
# 81    11
# 82    11
# 83    10
# 84    10
# 85    10
# 86    11
# 87    10
# 88    11
# 89    13
# 90     8
# 91    14
# 92     8
# 93    11
# 94    10
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins=15)

# %% [markdown]
# ## 05-05 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.1968526614594834

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe() #算出所有描述型的統計
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
df.corr() #eg.國文與英文之間的相關係數
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %% [markdown]
# ## 05-06 增加一行
#
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df['總級分'] = df.sum(axis=1)#總級分是(整個column)橫著加過去(對著上面表格看)

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會    總級分    加權
# 0  劉俊安   9  10  15  10  13  292.0  60.5
# 1  胡玉華  10  10  10   8   9  251.0  55.0
# 2  黃淑婷  13  15   8  11  14  319.0  68.0
# 3  陳上紫  10  10   8   9  14  257.0  52.0
# 4  崔靜成  13  12  14  12  13  334.0  71.0

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
df['加權']=df.英文*2+df.國文*2+df.數學*1.5

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會    總級分    加權
# 0  劉俊安   9  10  15  10  13  292.0  60.5
# 1  胡玉華  10  10  10   8   9  251.0  55.0
# 2  黃淑婷  13  15   8  11  14  319.0  68.0
# 3  陳上紫  10  10   8   9  14  257.0  52.0
# 4  崔靜成  13  12  14  12  13  334.0  71.0

# %% [markdown]
# ## 05-07 排序和 index 重設
#
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by='總級分',ascending=False).head(10)#從高排到低，前10名=>同分的太多了
# Out:
#      姓名  國文  英文  數學  自然  社會    總級分    加權
# 48  陳怡婷  15  14  12   9  15  347.0  76.0
# 80  施雅鈴  13  15  12  13  13  346.0  74.0
# 57  胡淳茜  12  15  14  13  11  345.0  75.0
# 54  陳怡潔  15  15   9  15  11  342.0  73.5
# 25  蔡亦瑄  13  13  14  13  12  341.0  73.0
# 36  詹威德  12  13  15  10  14  337.0  72.5
# 83  李士賢  10  14  15  13  13  336.0  70.5
# 12  李正偉  11  15  11  14  15  335.0  68.5
# 73  吳志遠  13  15  15   8   8  334.0  78.5
# 4   崔靜成  13  12  14  12  13  334.0  71.0

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df2=df.sort_values(by=['加權','總級分'],ascending=False)

# %%
df2.head()
# Out:
#      姓名  國文  英文  數學  自然  社會    總級分    加權
# 73  吳志遠  13  15  15   8   8  334.0  78.5
# 48  陳怡婷  15  14  12   9  15  347.0  76.0
# 57  胡淳茜  12  15  14  13  11  345.0  75.0
# 80  施雅鈴  13  15  12  13  13  346.0  74.0
# 54  陳怡潔  15  15   9  15  11  342.0  73.5

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index=range(1,101)#1,2,3,4...101

# %%
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會    總級分    加權
# 1  吳志遠  13  15  15   8   8  334.0  78.5
# 2  陳怡婷  15  14  12   9  15  347.0  76.0
# 3  胡淳茜  12  15  14  13  11  345.0  75.0
# 4  施雅鈴  13  15  12  13  13  346.0  74.0
# 5  陳怡潔  15  15   9  15  11  342.0  73.5

# %% [markdown]
# ## 05-08 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。
#
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df2.數學==15
# Out:
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
#        ...
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80      True
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# Name: 數學, Length: 100, dtype: bool

# %%
df2[df2.數學==15]
# Out:
#      姓名  國文  英文  數學  自然  社會    總級分    加權
# 1   吳志遠  13  15  15   8   8  334.0  78.5
# 9   詹威德  12  13  15  10  14  337.0  72.5
# 13  李士賢  10  14  15  13  13  336.0  70.5
# 20  曾怡君  11  12  15  13  14  332.0  68.5
# 21  林哲法  14   9  15  10  14  323.0  68.5
# 34  陳竹伯  10  12  15  10  14  316.0  66.5
# 37  葉儀依   9  13  15   8  14  310.0  66.5
# 44  周育霖   9  12  15  13  12  312.0  64.5
# 48  張雅彬  10  11  15  12   8  297.0  64.5
# 49  芮秋辛  11  10  15  10   8  291.0  64.5
# 67  胡勝傑   8  11  15  10  15  298.0  60.5
# 68  劉俊安   9  10  15  10  13  292.0  60.5
# 80  段冠廷   9   8  15  12  15  290.0  56.5

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
df2[(df2.數學==15) & (df2.英文>13)] # 要括弧
# Out:
#      姓名  國文  英文  數學  自然  社會    總級分    加權
# 1   吳志遠  13  15  15   8   8  334.0  78.5
# 13  李士賢  10  14  15  13  13  336.0  70.5

# %% [markdown]
# ## 05-09 刪除一行或一列
#
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會    總級分    加權
# 1  吳志遠  13  15  15   8   8  334.0  78.5
# 2  陳怡婷  15  14  12   9  15  347.0  76.0
# 3  胡淳茜  12  15  14  13  11  345.0  75.0
# 4  施雅鈴  13  15  12  13  13  346.0  74.0
# 5  陳怡潔  15  15   9  15  11  342.0  73.5

# %%
df2.drop('總級分',axis=1).head() #把總級分這行刪掉(axis=1)
# Out:
#     姓名  國文  英文  數學  自然  社會    加權
# 1  吳志遠  13  15  15   8   8  78.5
# 2  陳怡婷  15  14  12   9  15  76.0
# 3  胡淳茜  12  15  14  13  11  75.0
# 4  施雅鈴  13  15  12  13  13  74.0
# 5  陳怡潔  15  15   9  15  11  73.5

# %%
df2.head()#發現總級分還在，因為上面只drop，沒有寫回原來的df2
# Out:
#     姓名  國文  英文  數學  自然  社會    總級分    加權
# 1  吳志遠  13  15  15   8   8  334.0  78.5
# 2  陳怡婷  15  14  12   9  15  347.0  76.0
# 3  胡淳茜  12  15  14  13  11  345.0  75.0
# 4  施雅鈴  13  15  12  13  13  346.0  74.0
# 5  陳怡潔  15  15   9  15  11  342.0  73.5

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop('總級分',axis=1,inplace=True)

# %%
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會    加權
# 1  吳志遠  13  15  15   8   8  78.5
# 2  陳怡婷  15  14  12   9  15  76.0
# 3  胡淳茜  12  15  14  13  11  75.0
# 4  施雅鈴  13  15  12  13  13  74.0
# 5  陳怡潔  15  15   9  15  11  73.5

# %%
df2.drop(5).head()#把第五列的人去掉
# Out:
#     姓名  國文  英文  數學  自然  社會    加權
# 1  吳志遠  13  15  15   8   8  78.5
# 2  陳怡婷  15  14  12   9  15  76.0
# 3  胡淳茜  12  15  14  13  11  75.0
# 4  施雅鈴  13  15  12  13  13  74.0
# 6  謝雅琳  13  14  13  12   9  73.5

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2[df2.姓名=='施雅鈴'].index
# Out:
# Int64Index([4], dtype='int64')

# %%
df2.drop(df2[df2.姓名=='施雅鈴'].index).head()
# Out:
#     姓名  國文  英文  數學  自然  社會    加權
# 1  吳志遠  13  15  15   8   8  78.5
# 2  陳怡婷  15  14  12   9  15  76.0
# 3  胡淳茜  12  15  14  13  11  75.0
# 5  陳怡潔  15  15   9  15  11  73.5
# 6  謝雅琳  13  14  13  12   9  73.5

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2[df2.姓名!='施雅鈴'].head()
# Out:
#     姓名  國文  英文  數學  自然  社會    加權
# 1  吳志遠  13  15  15   8   8  78.5
# 2  陳怡婷  15  14  12   9  15  76.0
# 3  胡淳茜  12  15  14  13  11  75.0
# 5  陳怡潔  15  15   9  15  11  73.5
# 6  謝雅琳  13  14  13  12   9  73.5

# %% [markdown]
# ### 【重點】刪掉一列
#
# 聰明的你是不是想到, 那直接篩出我們要留的就好了啊!

# %% [markdown]
# ## 05-10 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader
#
# 要注意這些指令是要在終端機下的, 如果堅持不要離開 Jupyter Notebook 的安裝, 可以用:
#
#     !conda install pandas-datareader -y
#
# 你要記得下達 `-y` 這個動作, 不然你的電腦會永遠在那等你按 `y`, 但你其實按不了...

# %% [markdown]
# 我們把這個檔案以 `aapl.csv` 存起來, 之後可以這樣讀入。
#
#     df = pd.read_csv('dataset/aapl.csv', index_col="Date")

# %% [markdown]
# #### 只要最後 240 個交易日!

# %% [markdown]
# #### 20 日的移動平均

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %% [markdown]
# ## 05-11 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata=np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.87932145, -1.64836975,  1.20593593],
#        [ 0.38437761,  0.57315196,  0.25448169],
#        [ 0.68178892,  0.01048924, -1.66379252],
#        [-0.32691264,  1.38228432, -0.20313558]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df=pd.DataFrame(mydata,columns=list('ABC'))

# %%
df #df for DataFrame
# Out:
#           A         B         C
# 0 -0.879321 -1.648370  1.205936
# 1  0.384378  0.573152  0.254482
# 2  0.681789  0.010489 -1.663793
# 3 -0.326913  1.382284 -0.203136

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df2=pd.DataFrame(np.random.randn(3,3),columns=list('ABC'))

# %%
df2
# Out:
#           A         B         C
# 0 -0.446173 -1.010686  0.368057
# 1 -1.265258  0.280150  0.307200
# 2 -1.596164 -2.046146 -2.502249

# %%
df3=pd.concat([df,df2],axis=0)

# %%
df3
# Out:
#           A         B         C
# 0 -0.737146  0.745029 -1.210597
# 1  2.547548 -0.248421 -0.993503
# 2 -0.574962 -0.171648 -0.176017
# 0 -0.446173 -1.010686  0.368057
# 1 -1.265258  0.280150  0.307200
# 2 -1.596164 -2.046146 -2.502249

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %% [markdown]
# #### 横向的貼

# %%
df
# Out:
#           A         B         C
# 0 -0.737146  0.745029 -1.210597
# 1  2.547548 -0.248421 -0.993503
# 2 -0.574962 -0.171648 -0.176017

# %%
pd.concat([df,df2],axis=1)
# Out:
#           A         B         C         A         B         C
# 0 -0.737146  0.745029 -1.210597 -0.446173 -1.010686  0.368057
# 1  2.547548 -0.248421 -0.993503 -1.265258  0.280150  0.307200
# 2 -0.574962 -0.171648 -0.176017 -1.596164 -2.046146 -2.502249

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)
